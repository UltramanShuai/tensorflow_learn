# %% [markdown]
# # 学习率

# %%
import tensorflow as tf

# %%
w=tf.Variable(tf.constant(5,dtype=tf.float32))
# Out:
# WARNING:tensorflow:From C:\Programmer\Anaconda3\envs\python3_anaconda_env\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
loss=tf.square(w+1)

# %%
#train_step=tf.train.GradientDescentOptimizer(0.2).minimize(loss)
#train_step=tf.train.GradientDescentOptimizer(1).minimize(loss)
train_step=tf.train.GradientDescentOptimizer(0.0001).minimize(loss)

# %%
with tf.Session() as sess:
    init_op=tf.global_variables_initializer()
    sess.run(init_op)
    for i in range(4000):
        sess.run(train_step)
        w_val=sess.run(w)
        loss_val=sess.run(loss)
        print("After %s step : w is %f, loss is %f ."%(i,w_val,loss_val))
# Out:
# After 0 step : w is 4.998800, loss is 35.985600 .
# After 1 step : w is 4.997600, loss is 35.971207 .
# After 2 step : w is 4.996400, loss is 35.956818 .
# After 3 step : w is 4.995201, loss is 35.942436 .
# After 4 step : w is 4.994002, loss is 35.928059 .
# After 5 step : w is 4.992803, loss is 35.913689 .
# After 6 step : w is 4.991604, loss is 35.899323 .
# After 7 step : w is 4.990406, loss is 35.884964 .
# After 8 step : w is 4.989208, loss is 35.870609 .
# After 9 step : w is 4.988010, loss is 35.856262 .
# After 10 step : w is 4.986812, loss is 35.841919 .
# After 11 step : w is 4.985615, loss is 35.827583 .
# After 12 step : w is 4.984417, loss is 35.813251 .
# After 13 step : w is 4.983221, loss is 35.798927 .
# After 14 step : w is 4.982024, loss is 35.784607 .
# After 15 step : w is 4.980827, loss is 35.770294 .
# After 16 step : w is 4.979631, loss is 35.755985 .
# After 17 step : w is 4.978435, loss is 35.741684 .
# After 18 step : w is 4.977239, loss is 35.727386 .
# After 19 step : w is 4.976044, loss is 35.713097 .
# After 20 step : w is 4.974848, loss is 35.698811 .
# After 21 step : w is 4.973653, loss is 35.684532 .
# After 22 step : w is 4.972458, loss is 35.670258 .
# After 23 step : w is 4.971264, loss is 35.655991 .
# After 24 step : w is 4.970069, loss is 35.641727 .
# After 25 step : w is 4.968875, loss is 35.627472 .
# After 26 step : w is 4.967681, loss is 35.613220 .
# After 27 step : w is 4.966488, loss is 35.598976 .
# After 28 step : w is 4.965294, loss is 35.584736 .
# After 29 step : w is 4.964101, loss is 35.570503 .
# After 30 step : w is 4.962908, loss is 35.556274 .
# After 31 step : w is 4.961716, loss is 35.542053 .
# After 32 step : w is 4.960523, loss is 35.527836 .
# After 33 step : w is 4.959331, loss is 35.513626 .
# After 34 step : w is 4.958139, loss is 35.499420 .
# After 35 step : w is 4.956947, loss is 35.485222 .
# After 36 step : w is 4.955756, loss is 35.471027 .
# After 37 step : w is 4.954565, loss is 35.456841 .
# After 38 step : w is 4.953373, loss is 35.442654 .
# After 39 step : w is 4.952183, loss is 35.428478 .
# After 40 step : w is 4.950992, loss is 35.414307 .
# After 41 step : w is 4.949802, loss is 35.400143 .
# After 42 step : w is 4.948612, loss is 35.385983 .
# After 43 step : w is 4.947422, loss is 35.371830 .
# After 44 step : w is 4.946232, loss is 35.357677 .
# After 45 step : w is 4.945043, loss is 35.343536 .
# After 46 step : w is 4.943854, loss is 35.329399 .
# After 47 step : w is 4.942665, loss is 35.315269 .
# After 48 step : w is 4.941476, loss is 35.301140 .
# After 49 step : w is 4.940288, loss is 35.287022 .
# After 50 step : w is 4.939100, loss is 35.272907 .
# After 51 step : w is 4.937912, loss is 35.258801 .
# After 52 step : w is 4.936724, loss is 35.244694 .
# After 53 step : w is 4.935537, loss is 35.230598 .
# After 54 step : w is 4.934350, loss is 35.216503 .
# After 55 step : w is 4.933163, loss is 35.202419 .
# After 56 step : w is 4.931976, loss is 35.188339 .
# After 57 step : w is 4.930789, loss is 35.174263 .
# After 58 step : w is 4.929603, loss is 35.160194 .
# After 59 step : w is 4.928417, loss is 35.146130 .
# After 60 step : w is 4.927231, loss is 35.132072 .
# After 61 step : w is 4.926046, loss is 35.118019 .
# After 62 step : w is 4.924860, loss is 35.103973 .
# After 63 step : w is 4.923676, loss is 35.089931 .
# After 64 step : w is 4.922491, loss is 35.075893 .
# After 65 step : w is 4.921306, loss is 35.061867 .
# After 66 step : w is 4.920122, loss is 35.047840 .
# After 67 step : w is 4.918938, loss is 35.033825 .
# After 68 step : w is 4.917754, loss is 35.019810 .
# After 69 step : w is 4.916570, loss is 35.005802 .
# After 70 step : w is 4.915387, loss is 34.991798 .
# After 71 step : w is 4.914204, loss is 34.977806 .
# After 72 step : w is 4.913021, loss is 34.963814 .
# After 73 step : w is 4.911838, loss is 34.949829 .
# After 74 step : w is 4.910655, loss is 34.935848 .
# After 75 step : w is 4.909473, loss is 34.921875 .
# After 76 step : w is 4.908291, loss is 34.907906 .
# After 77 step : w is 4.907110, loss is 34.893944 .
# After 78 step : w is 4.905928, loss is 34.879986 .
# After 79 step : w is 4.904747, loss is 34.866035 .
# After 80 step : w is 4.903566, loss is 34.852089 .
# After 81 step : w is 4.902385, loss is 34.838150 .
# After 82 step : w is 4.901205, loss is 34.824215 .
# After 83 step : w is 4.900024, loss is 34.810287 .
# After 84 step : w is 4.898844, loss is 34.796364 .
# After 85 step : w is 4.897665, loss is 34.782448 .
# After 86 step : w is 4.896485, loss is 34.768532 .
# After 87 step : w is 4.895306, loss is 34.754627 .
# After 88 step : w is 4.894126, loss is 34.740726 .
# After 89 step : w is 4.892948, loss is 34.726833 .
# After 90 step : w is 4.891769, loss is 34.712940 .
# After 91 step : w is 4.890591, loss is 34.699059 .
# After 92 step : w is 4.889412, loss is 34.685177 .
# After 93 step : w is 4.888235, loss is 34.671307 .
# After 94 step : w is 4.887057, loss is 34.657436 .
# After 95 step : w is 4.885880, loss is 34.643578 .
# After 96 step : w is 4.884702, loss is 34.629719 .
# After 97 step : w is 4.883525, loss is 34.615871 .
# After 98 step : w is 4.882349, loss is 34.602024 .
# After 99 step : w is 4.881172, loss is 34.588184 .
# After 100 step : w is 4.879996, loss is 34.574352 .
# After 101 step : w is 4.878820, loss is 34.560524 .
# After 102 step : w is 4.877644, loss is 34.546700 .
# After 103 step : w is 4.876469, loss is 34.532883 .
# After 104 step : w is 4.875293, loss is 34.519070 .
# After 105 step : w is 4.874118, loss is 34.505264 .
# After 106 step : w is 4.872943, loss is 34.491463 .
# After 107 step : w is 4.871769, loss is 34.477669 .
# After 108 step : w is 4.870595, loss is 34.463879 .
# After 109 step : w is 4.869421, loss is 34.450096 .
# After 110 step : w is 4.868247, loss is 34.436317 .
# After 111 step : w is 4.867073, loss is 34.422546 .
# After 112 step : w is 4.865900, loss is 34.408779 .
# After 113 step : w is 4.864727, loss is 34.395016 .
# After 114 step : w is 4.863554, loss is 34.381260 .
# After 115 step : w is 4.862381, loss is 34.367512 .
# After 116 step : w is 4.861208, loss is 34.353764 .
# After 117 step : w is 4.860036, loss is 34.340027 .
# After 118 step : w is 4.858864, loss is 34.326290 .
# After 119 step : w is 4.857693, loss is 34.312565 .
# After 120 step : w is 4.856521, loss is 34.298840 .
# After 121 step : w is 4.855350, loss is 34.285126 .
# After 122 step : w is 4.854179, loss is 34.271412 .
# After 123 step : w is 4.853008, loss is 34.257706 .
# After 124 step : w is 4.851838, loss is 34.244003 .
# After 125 step : w is 4.850667, loss is 34.230309 .
# After 126 step : w is 4.849497, loss is 34.216618 .
# After 127 step : w is 4.848328, loss is 34.202934 .
# After 128 step : w is 4.847158, loss is 34.189255 .
# After 129 step : w is 4.845989, loss is 34.175583 .
# After 130 step : w is 4.844820, loss is 34.161915 .
# After 131 step : w is 4.843651, loss is 34.148254 .
# After 132 step : w is 4.842482, loss is 34.134598 .
# After 133 step : w is 4.841313, loss is 34.120941 .
# After 134 step : w is 4.840145, loss is 34.107296 .
# After 135 step : w is 4.838977, loss is 34.093651 .
# After 136 step : w is 4.837809, loss is 34.080013 .
# After 137 step : w is 4.836641, loss is 34.066383 .
# After 138 step : w is 4.835474, loss is 34.052757 .
# After 139 step : w is 4.834307, loss is 34.039135 .
# After 140 step : w is 4.833140, loss is 34.025520 .
# After 141 step : w is 4.831973, loss is 34.011909 .
# After 142 step : w is 4.830807, loss is 33.998306 .
# After 143 step : w is 4.829640, loss is 33.984707 .
# After 144 step : w is 4.828475, loss is 33.971115 .
# After 145 step : w is 4.827309, loss is 33.957527 .
# After 146 step : w is 4.826143, loss is 33.943947 .
# After 147 step : w is 4.824978, loss is 33.930367 .
# After 148 step : w is 4.823813, loss is 33.916798 .
# After 149 step : w is 4.822648, loss is 33.903229 .
# After 150 step : w is 4.821484, loss is 33.889671 .
# After 151 step : w is 4.820319, loss is 33.876114 .
# After 152 step : w is 4.819155, loss is 33.862568 .
# After 153 step : w is 4.817991, loss is 33.849022 .
# After 154 step : w is 4.816828, loss is 33.835484 .
# After 155 step : w is 4.815664, loss is 33.821953 .
# After 156 step : w is 4.814501, loss is 33.808426 .
# After 157 step : w is 4.813338, loss is 33.794903 .
# After 158 step : w is 4.812176, loss is 33.781387 .
# After 159 step : w is 4.811013, loss is 33.767876 .
# After 160 step : w is 4.809851, loss is 33.754372 .
# After 161 step : w is 4.808689, loss is 33.740868 .
# After 162 step : w is 4.807528, loss is 33.727375 .
# After 163 step : w is 4.806366, loss is 33.713886 .
# After 164 step : w is 4.805205, loss is 33.700405 .
# After 165 step : w is 4.804044, loss is 33.686924 .
# After 166 step : w is 4.802883, loss is 33.673454 .
# After 167 step : w is 4.801723, loss is 33.659985 .
# After 168 step : w is 4.800562, loss is 33.646523 .
# After 169 step : w is 4.799402, loss is 33.633068 .
# After 170 step : w is 4.798243, loss is 33.619617 .
# After 171 step : w is 4.797083, loss is 33.606171 .
# After 172 step : w is 4.795924, loss is 33.592731 .
# After 173 step : w is 4.794765, loss is 33.579296 .
# After 174 step : w is 4.793605, loss is 33.565865 .
# After 175 step : w is 4.792447, loss is 33.552437 .
# After 176 step : w is 4.791288, loss is 33.539017 .
# After 177 step : w is 4.790130, loss is 33.525600 .
# After 178 step : w is 4.788971, loss is 33.512192 .
# After 179 step : w is 4.787814, loss is 33.498787 .
# After 180 step : w is 4.786656, loss is 33.485386 .
# After 181 step : w is 4.785499, loss is 33.471992 .
# After 182 step : w is 4.784341, loss is 33.458603 .
# After 183 step : w is 4.783185, loss is 33.445225 .
# After 184 step : w is 4.782028, loss is 33.431843 .
# After 185 step : w is 4.780871, loss is 33.418472 .
# After 186 step : w is 4.779715, loss is 33.405106 .
# After 187 step : w is 4.778559, loss is 33.391747 .
# After 188 step : w is 4.777403, loss is 33.378391 .
# After 189 step : w is 4.776248, loss is 33.365040 .
# After 190 step : w is 4.775093, loss is 33.351696 .
# After 191 step : w is 4.773938, loss is 33.338356 .
# After 192 step : w is 4.772783, loss is 33.325020 .
# After 193 step : w is 4.771628, loss is 33.311695 .
# After 194 step : w is 4.770474, loss is 33.298370 .
# After 195 step : w is 4.769320, loss is 33.285053 .
# After 196 step : w is 4.768166, loss is 33.271740 .
# After 197 step : w is 4.767013, loss is 33.258434 .
# After 198 step : w is 4.765859, loss is 33.245132 .
# After 199 step : w is 4.764706, loss is 33.231838 .
# After 200 step : w is 4.763553, loss is 33.218544 .
# After 201 step : w is 4.762401, loss is 33.205261 .
# After 202 step : w is 4.761248, loss is 33.191978 .
# After 203 step : w is 4.760096, loss is 33.178707 .
# After 204 step : w is 4.758944, loss is 33.165436 .
# After 205 step : w is 4.757792, loss is 33.152176 .
# After 206 step : w is 4.756641, loss is 33.138916 .
# After 207 step : w is 4.755489, loss is 33.125656 .
# After 208 step : w is 4.754338, loss is 33.112408 .
# After 209 step : w is 4.753187, loss is 33.099163 .
# After 210 step : w is 4.752037, loss is 33.085926 .
# After 211 step : w is 4.750886, loss is 33.072689 .
# After 212 step : w is 4.749736, loss is 33.059464 .
# After 213 step : w is 4.748586, loss is 33.046238 .
# After 214 step : w is 4.747436, loss is 33.033020 .
# After 215 step : w is 4.746286, loss is 33.019806 .
# After 216 step : w is 4.745137, loss is 33.006603 .
# After 217 step : w is 4.743988, loss is 32.993397 .
# After 218 step : w is 4.742839, loss is 32.980206 .
# After 219 step : w is 4.741691, loss is 32.967010 .
# After 220 step : w is 4.740542, loss is 32.953827 .
# After 221 step : w is 4.739394, loss is 32.940647 .
# After 222 step : w is 4.738246, loss is 32.927471 .
# After 223 step : w is 4.737099, loss is 32.914303 .
# After 224 step : w is 4.735951, loss is 32.901138 .
# After 225 step : w is 4.734804, loss is 32.887978 .
# After 226 step : w is 4.733657, loss is 32.874828 .
# After 227 step : w is 4.732511, loss is 32.861679 .
# After 228 step : w is 4.731364, loss is 32.848537 .
# After 229 step : w is 4.730218, loss is 32.835396 .
# After 230 step : w is 4.729072, loss is 32.822266 .
# After 231 step : w is 4.727926, loss is 32.809139 .
# After 232 step : w is 4.726781, loss is 32.796021 .
# After 233 step : w is 4.725636, loss is 32.782902 .
# After 234 step : w is 4.724490, loss is 32.769787 .
# After 235 step : w is 4.723345, loss is 32.756680 .
# After 236 step : w is 4.722200, loss is 32.743576 .
# After 237 step : w is 4.721056, loss is 32.730480 .
# After 238 step : w is 4.719912, loss is 32.717388 .
# After 239 step : w is 4.718768, loss is 32.704304 .
# After 240 step : w is 4.717624, loss is 32.691219 .
# After 241 step : w is 4.716480, loss is 32.678146 .
# After 242 step : w is 4.715337, loss is 32.665073 .
# After 243 step : w is 4.714194, loss is 32.652012 .
# After 244 step : w is 4.713051, loss is 32.638950 .
# After 245 step : w is 4.711908, loss is 32.625896 .
# After 246 step : w is 4.710766, loss is 32.612846 .
# After 247 step : w is 4.709624, loss is 32.599804 .
# After 248 step : w is 4.708482, loss is 32.586765 .
# After 249 step : w is 4.707340, loss is 32.573734 .
# After 250 step : w is 4.706199, loss is 32.560703 .
# After 251 step : w is 4.705058, loss is 32.547684 .
# After 252 step : w is 4.703917, loss is 32.534664 .
# After 253 step : w is 4.702776, loss is 32.521652 .
# After 254 step : w is 4.701635, loss is 32.508644 .
# After 255 step : w is 4.700495, loss is 32.495647 .
# After 256 step : w is 4.699355, loss is 32.482647 .
# After 257 step : w is 4.698215, loss is 32.469658 .
# After 258 step : w is 4.697076, loss is 32.456673 .
# After 259 step : w is 4.695936, loss is 32.443687 .
# After 260 step : w is 4.694797, loss is 32.430714 .
# After 261 step : w is 4.693658, loss is 32.417740 .
# After 262 step : w is 4.692519, loss is 32.404774 .
# After 263 step : w is 4.691381, loss is 32.391811 .
# After 264 step : w is 4.690242, loss is 32.378857 .
# After 265 step : w is 4.689104, loss is 32.365906 .
# After 266 step : w is 4.687966, loss is 32.352962 .
# After 267 step : w is 4.686829, loss is 32.340019 .
# After 268 step : w is 4.685691, loss is 32.327087 .
# After 269 step : w is 4.684554, loss is 32.314156 .
# After 270 step : w is 4.683417, loss is 32.301231 .
# After 271 step : w is 4.682281, loss is 32.288311 .
# After 272 step : w is 4.681144, loss is 32.275398 .
# After 273 step : w is 4.680008, loss is 32.262489 .
# After 274 step : w is 4.678872, loss is 32.249588 .
# After 275 step : w is 4.677736, loss is 32.236691 .
# After 276 step : w is 4.676601, loss is 32.223797 .
# After 277 step : w is 4.675466, loss is 32.210911 .
# After 278 step : w is 4.674331, loss is 32.198029 .
# After 279 step : w is 4.673196, loss is 32.185150 .
# After 280 step : w is 4.672061, loss is 32.172276 .
# After 281 step : w is 4.670927, loss is 32.159409 .
# After 282 step : w is 4.669792, loss is 32.146542 .
# After 283 step : w is 4.668658, loss is 32.133686 .
# After 284 step : w is 4.667524, loss is 32.120831 .
# After 285 step : w is 4.666391, loss is 32.107986 .
# After 286 step : w is 4.665257, loss is 32.095142 .
# After 287 step : w is 4.664124, loss is 32.082306 .
# After 288 step : w is 4.662992, loss is 32.069473 .
# After 289 step : w is 4.661859, loss is 32.056648 .
# After 290 step : w is 4.660727, loss is 32.043823 .
# After 291 step : w is 4.659595, loss is 32.031010 .
# After 292 step : w is 4.658463, loss is 32.018200 .
# After 293 step : w is 4.657331, loss is 32.005394 .
# After 294 step : w is 4.656199, loss is 31.992592 .
# After 295 step : w is 4.655068, loss is 31.979799 .
# After 296 step : w is 4.653937, loss is 31.967007 .
# After 297 step : w is 4.652807, loss is 31.954224 .
# After 298 step : w is 4.651676, loss is 31.941444 .
# After 299 step : w is 4.650546, loss is 31.928671 .
# After 300 step : w is 4.649416, loss is 31.915901 .
# After 301 step : w is 4.648286, loss is 31.903133 .
# After 302 step : w is 4.647156, loss is 31.890373 .
# After 303 step : w is 4.646027, loss is 31.877617 .
# After 304 step : w is 4.644897, loss is 31.864868 .
# After 305 step : w is 4.643768, loss is 31.852121 .
# After 306 step : w is 4.642640, loss is 31.839382 .
# After 307 step : w is 4.641511, loss is 31.826647 .
# After 308 step : w is 4.640383, loss is 31.813917 .
# After 309 step : w is 4.639255, loss is 31.801191 .
# After 310 step : w is 4.638127, loss is 31.788475 .
# After 311 step : w is 4.636999, loss is 31.775759 .
# After 312 step : w is 4.635872, loss is 31.763052 .
# After 313 step : w is 4.634745, loss is 31.750347 .
# After 314 step : w is 4.633618, loss is 31.737650 .
# After 315 step : w is 4.632491, loss is 31.724957 .
# After 316 step : w is 4.631365, loss is 31.712269 .
# After 317 step : w is 4.630239, loss is 31.699587 .
# After 318 step : w is 4.629113, loss is 31.686911 .
# After 319 step : w is 4.627987, loss is 31.674236 .
# After 320 step : w is 4.626861, loss is 31.661566 .
# After 321 step : w is 4.625736, loss is 31.648903 .
# After 322 step : w is 4.624610, loss is 31.636242 .
# After 323 step : w is 4.623486, loss is 31.623590 .
# After 324 step : w is 4.622361, loss is 31.610939 .
# After 325 step : w is 4.621236, loss is 31.598297 .
# After 326 step : w is 4.620112, loss is 31.585659 .
# After 327 step : w is 4.618988, loss is 31.573027 .
# After 328 step : w is 4.617864, loss is 31.560398 .
# After 329 step : w is 4.616741, loss is 31.547775 .
# After 330 step : w is 4.615617, loss is 31.535158 .
# After 331 step : w is 4.614494, loss is 31.522547 .
# After 332 step : w is 4.613371, loss is 31.509937 .
# After 333 step : w is 4.612249, loss is 31.497337 .
# After 334 step : w is 4.611126, loss is 31.484739 .
# After 335 step : w is 4.610004, loss is 31.472149 .
# After 336 step : w is 4.608882, loss is 31.459562 .
# After 337 step : w is 4.607760, loss is 31.446978 .
# After 338 step : w is 4.606639, loss is 31.434401 .
# After 339 step : w is 4.605517, loss is 31.421825 .
# After 340 step : w is 4.604396, loss is 31.409258 .
# After 341 step : w is 4.603275, loss is 31.396694 .
# After 342 step : w is 4.602155, loss is 31.384138 .
# After 343 step : w is 4.601034, loss is 31.371584 .
# After 344 step : w is 4.599914, loss is 31.359037 .
# After 345 step : w is 4.598794, loss is 31.346495 .
# After 346 step : w is 4.597674, loss is 31.333958 .
# After 347 step : w is 4.596555, loss is 31.321424 .
# After 348 step : w is 4.595436, loss is 31.308899 .
# After 349 step : w is 4.594316, loss is 31.296377 .
# After 350 step : w is 4.593198, loss is 31.283861 .
# After 351 step : w is 4.592079, loss is 31.271349 .
# After 352 step : w is 4.590961, loss is 31.258844 .
# After 353 step : w is 4.589843, loss is 31.246342 .
# After 354 step : w is 4.588725, loss is 31.233843 .
# After 355 step : w is 4.587607, loss is 31.221352 .
# After 356 step : w is 4.586489, loss is 31.208862 .
# After 357 step : w is 4.585372, loss is 31.196381 .
# After 358 step : w is 4.584255, loss is 31.183901 .
# After 359 step : w is 4.583138, loss is 31.171431 .
# After 360 step : w is 4.582021, loss is 31.158960 .
# After 361 step : w is 4.580905, loss is 31.146500 .
# After 362 step : w is 4.579789, loss is 31.134041 .
# After 363 step : w is 4.578673, loss is 31.121592 .
# After 364 step : w is 4.577557, loss is 31.109142 .
# After 365 step : w is 4.576442, loss is 31.096703 .
# After 366 step : w is 4.575326, loss is 31.084265 .
# After 367 step : w is 4.574212, loss is 31.071835 .
# After 368 step : w is 4.573097, loss is 31.059408 .
# After 369 step : w is 4.571982, loss is 31.046982 .
# After 370 step : w is 4.570868, loss is 31.034565 .
# After 371 step : w is 4.569753, loss is 31.022150 .
# After 372 step : w is 4.568639, loss is 31.009743 .
# After 373 step : w is 4.567525, loss is 30.997339 .
# After 374 step : w is 4.566412, loss is 30.984941 .
# After 375 step : w is 4.565299, loss is 30.972548 .
# After 376 step : w is 4.564186, loss is 30.960161 .
# After 377 step : w is 4.563073, loss is 30.947777 .
# After 378 step : w is 4.561960, loss is 30.935402 .
# After 379 step : w is 4.560848, loss is 30.923027 .
# After 380 step : w is 4.559736, loss is 30.910662 .
# After 381 step : w is 4.558624, loss is 30.898298 .
# After 382 step : w is 4.557512, loss is 30.885942 .
# After 383 step : w is 4.556401, loss is 30.873590 .
# After 384 step : w is 4.555289, loss is 30.861238 .
# After 385 step : w is 4.554178, loss is 30.848896 .
# After 386 step : w is 4.553067, loss is 30.836555 .
# After 387 step : w is 4.551957, loss is 30.824223 .
# After 388 step : w is 4.550846, loss is 30.811892 .
# After 389 step : w is 4.549736, loss is 30.799570 .
# After 390 step : w is 4.548626, loss is 30.787251 .
# After 391 step : w is 4.547516, loss is 30.774937 .
# After 392 step : w is 4.546407, loss is 30.762629 .
# After 393 step : w is 4.545298, loss is 30.750326 .
# After 394 step : w is 4.544188, loss is 30.738026 .
# After 395 step : w is 4.543080, loss is 30.725735 .
# After 396 step : w is 4.541971, loss is 30.713446 .
# After 397 step : w is 4.540863, loss is 30.701162 .
# After 398 step : w is 4.539755, loss is 30.688885 .
# After 399 step : w is 4.538647, loss is 30.676607 .
# After 400 step : w is 4.537539, loss is 30.664339 .
# After 401 step : w is 4.536431, loss is 30.652071 .
# After 402 step : w is 4.535324, loss is 30.639812 .
# After 403 step : w is 4.534217, loss is 30.627556 .
# After 404 step : w is 4.533110, loss is 30.615309 .
# After 405 step : w is 4.532003, loss is 30.603062 .
# After 406 step : w is 4.530897, loss is 30.590824 .
# After 407 step : w is 4.529791, loss is 30.578587 .
# After 408 step : w is 4.528685, loss is 30.566359 .
# After 409 step : w is 4.527579, loss is 30.554132 .
# After 410 step : w is 4.526474, loss is 30.541914 .
# After 411 step : w is 4.525369, loss is 30.529699 .
# After 412 step : w is 4.524263, loss is 30.517487 .
# After 413 step : w is 4.523159, loss is 30.505280 .
# After 414 step : w is 4.522054, loss is 30.493076 .
# After 415 step : w is 4.520949, loss is 30.480883 .
# After 416 step : w is 4.519845, loss is 30.468689 .
# After 417 step : w is 4.518741, loss is 30.456503 .
# After 418 step : w is 4.517637, loss is 30.444321 .
# After 419 step : w is 4.516534, loss is 30.432146 .
# After 420 step : w is 4.515430, loss is 30.419973 .
# After 421 step : w is 4.514328, loss is 30.407808 .
# After 422 step : w is 4.513225, loss is 30.395645 .
# After 423 step : w is 4.512122, loss is 30.383492 .
# After 424 step : w is 4.511020, loss is 30.371338 .
# After 425 step : w is 4.509918, loss is 30.359194 .
# After 426 step : w is 4.508816, loss is 30.347052 .
# After 427 step : w is 4.507714, loss is 30.334911 .
# After 428 step : w is 4.506612, loss is 30.322779 .
# After 429 step : w is 4.505511, loss is 30.310650 .
# After 430 step : w is 4.504410, loss is 30.298527 .
# After 431 step : w is 4.503309, loss is 30.286407 .
# After 432 step : w is 4.502208, loss is 30.274296 .
# After 433 step : w is 4.501108, loss is 30.262186 .
# After 434 step : w is 4.500008, loss is 30.250084 .
# After 435 step : w is 4.498908, loss is 30.237984 .
# After 436 step : w is 4.497808, loss is 30.225893 .
# After 437 step : w is 4.496708, loss is 30.213802 .
# After 438 step : w is 4.495609, loss is 30.201721 .
# After 439 step : w is 4.494510, loss is 30.189642 .
# After 440 step : w is 4.493411, loss is 30.177565 .
# After 441 step : w is 4.492312, loss is 30.165495 .
# After 442 step : w is 4.491214, loss is 30.153429 .
# After 443 step : w is 4.490116, loss is 30.141369 .
# After 444 step : w is 4.489017, loss is 30.129313 .
# After 445 step : w is 4.487920, loss is 30.117264 .
# After 446 step : w is 4.486822, loss is 30.105217 .
# After 447 step : w is 4.485725, loss is 30.093178 .
# After 448 step : w is 4.484628, loss is 30.081141 .
# After 449 step : w is 4.483531, loss is 30.069113 .
# After 450 step : w is 4.482434, loss is 30.057085 .
# After 451 step : w is 4.481338, loss is 30.045067 .
# After 452 step : w is 4.480242, loss is 30.033051 .
# After 453 step : w is 4.479146, loss is 30.021036 .
# After 454 step : w is 4.478050, loss is 30.009029 .
# After 455 step : w is 4.476954, loss is 29.997025 .
# After 456 step : w is 4.475859, loss is 29.985029 .
# After 457 step : w is 4.474763, loss is 29.973034 .
# After 458 step : w is 4.473669, loss is 29.961048 .
# After 459 step : w is 4.472574, loss is 29.949064 .
# After 460 step : w is 4.471479, loss is 29.937086 .
# After 461 step : w is 4.470385, loss is 29.925114 .
# After 462 step : w is 4.469291, loss is 29.913147 .
# After 463 step : w is 4.468197, loss is 29.901182 .
# After 464 step : w is 4.467103, loss is 29.889221 .
# After 465 step : w is 4.466010, loss is 29.877266 .
# After 466 step : w is 4.464917, loss is 29.865314 .
# After 467 step : w is 4.463824, loss is 29.853371 .
# After 468 step : w is 4.462731, loss is 29.841429 .
# After 469 step : w is 4.461638, loss is 29.829494 .
# After 470 step : w is 4.460546, loss is 29.817562 .
# After 471 step : w is 4.459454, loss is 29.805639 .
# After 472 step : w is 4.458362, loss is 29.793716 .
# After 473 step : w is 4.457271, loss is 29.781803 .
# After 474 step : w is 4.456179, loss is 29.769892 .
# After 475 step : w is 4.455088, loss is 29.757986 .
# After 476 step : w is 4.453997, loss is 29.746084 .
# After 477 step : w is 4.452906, loss is 29.734186 .
# After 478 step : w is 4.451816, loss is 29.722294 .
# After 479 step : w is 4.450725, loss is 29.710403 .
# After 480 step : w is 4.449635, loss is 29.698523 .
# After 481 step : w is 4.448545, loss is 29.686642 .
# After 482 step : w is 4.447455, loss is 29.674770 .
# After 483 step : w is 4.446366, loss is 29.662901 .
# After 484 step : w is 4.445277, loss is 29.651039 .
# After 485 step : w is 4.444188, loss is 29.639179 .
# After 486 step : w is 4.443099, loss is 29.627327 .
# After 487 step : w is 4.442010, loss is 29.615477 .
# After 488 step : w is 4.440922, loss is 29.603630 .
# After 489 step : w is 4.439834, loss is 29.591789 .
# After 490 step : w is 4.438745, loss is 29.579952 .
# After 491 step : w is 4.437658, loss is 29.568123 .
# After 492 step : w is 4.436570, loss is 29.556295 .
# After 493 step : w is 4.435483, loss is 29.544476 .
# After 494 step : w is 4.434396, loss is 29.532658 .
# After 495 step : w is 4.433309, loss is 29.520847 .
# After 496 step : w is 4.432222, loss is 29.509039 .
# After 497 step : w is 4.431136, loss is 29.497240 .
# After 498 step : w is 4.430050, loss is 29.485441 .
# After 499 step : w is 4.428964, loss is 29.473646 .
# After 500 step : w is 4.427878, loss is 29.461859 .
# After 501 step : w is 4.426792, loss is 29.450073 .
# After 502 step : w is 4.425707, loss is 29.438295 .
# After 503 step : w is 4.424622, loss is 29.426519 .
# After 504 step : w is 4.423537, loss is 29.414751 .
# After 505 step : w is 4.422452, loss is 29.402985 .
# After 506 step : w is 4.421368, loss is 29.391228 .
# After 507 step : w is 4.420283, loss is 29.379471 .
# After 508 step : w is 4.419199, loss is 29.367723 .
# After 509 step : w is 4.418116, loss is 29.355976 .
# After 510 step : w is 4.417032, loss is 29.344233 .
# After 511 step : w is 4.415948, loss is 29.332497 .
# After 512 step : w is 4.414865, loss is 29.320763 .
# After 513 step : w is 4.413782, loss is 29.309036 .
# After 514 step : w is 4.412699, loss is 29.297314 .
# After 515 step : w is 4.411617, loss is 29.285597 .
# After 516 step : w is 4.410534, loss is 29.273882 .
# After 517 step : w is 4.409452, loss is 29.262177 .
# After 518 step : w is 4.408370, loss is 29.250471 .
# After 519 step : w is 4.407289, loss is 29.238775 .
# After 520 step : w is 4.406208, loss is 29.227079 .
# After 521 step : w is 4.405126, loss is 29.215387 .
# After 522 step : w is 4.404045, loss is 29.203703 .
# After 523 step : w is 4.402964, loss is 29.192020 .
# After 524 step : w is 4.401884, loss is 29.180346 .
# After 525 step : w is 4.400803, loss is 29.168674 .
# After 526 step : w is 4.399723, loss is 29.157009 .
# After 527 step : w is 4.398643, loss is 29.145346 .
# After 528 step : w is 4.397563, loss is 29.133692 .
# After 529 step : w is 4.396484, loss is 29.122038 .
# After 530 step : w is 4.395405, loss is 29.110394 .
# After 531 step : w is 4.394326, loss is 29.098751 .
# After 532 step : w is 4.393247, loss is 29.087109 .
# After 533 step : w is 4.392168, loss is 29.075476 .
# After 534 step : w is 4.391089, loss is 29.063845 .
# After 535 step : w is 4.390011, loss is 29.052221 .
# After 536 step : w is 4.388933, loss is 29.040602 .
# After 537 step : w is 4.387856, loss is 29.028988 .
# After 538 step : w is 4.386778, loss is 29.017376 .
# After 539 step : w is 4.385701, loss is 29.005772 .
# After 540 step : w is 4.384624, loss is 28.994171 .
# After 541 step : w is 4.383547, loss is 28.982576 .
# After 542 step : w is 4.382470, loss is 28.970985 .
# After 543 step : w is 4.381393, loss is 28.959394 .
# After 544 step : w is 4.380317, loss is 28.947813 .
# After 545 step : w is 4.379241, loss is 28.936234 .
# After 546 step : w is 4.378165, loss is 28.924662 .
# After 547 step : w is 4.377090, loss is 28.913092 .
# After 548 step : w is 4.376014, loss is 28.901529 .
# After 549 step : w is 4.374939, loss is 28.889969 .
# After 550 step : w is 4.373864, loss is 28.878416 .
# After 551 step : w is 4.372789, loss is 28.866865 .
# After 552 step : w is 4.371715, loss is 28.855318 .
# After 553 step : w is 4.370640, loss is 28.843777 .
# After 554 step : w is 4.369566, loss is 28.832239 .
# After 555 step : w is 4.368492, loss is 28.820707 .
# After 556 step : w is 4.367418, loss is 28.809179 .
# After 557 step : w is 4.366345, loss is 28.797657 .
# After 558 step : w is 4.365272, loss is 28.786139 .
# After 559 step : w is 4.364199, loss is 28.774628 .
# After 560 step : w is 4.363126, loss is 28.763119 .
# After 561 step : w is 4.362053, loss is 28.751617 .
# After 562 step : w is 4.360981, loss is 28.740118 .
# After 563 step : w is 4.359909, loss is 28.728621 .
# After 564 step : w is 4.358837, loss is 28.717131 .
# After 565 step : w is 4.357765, loss is 28.705643 .
# After 566 step : w is 4.356693, loss is 28.694162 .
# After 567 step : w is 4.355622, loss is 28.682686 .
# After 568 step : w is 4.354551, loss is 28.671215 .
# After 569 step : w is 4.353480, loss is 28.659746 .
# After 570 step : w is 4.352409, loss is 28.648287 .
# After 571 step : w is 4.351339, loss is 28.636827 .
# After 572 step : w is 4.350268, loss is 28.625372 .
# After 573 step : w is 4.349198, loss is 28.613922 .
# After 574 step : w is 4.348128, loss is 28.602476 .
# After 575 step : w is 4.347059, loss is 28.591038 .
# After 576 step : w is 4.345989, loss is 28.579601 .
# After 577 step : w is 4.344920, loss is 28.568171 .
# After 578 step : w is 4.343851, loss is 28.556744 .
# After 579 step : w is 4.342782, loss is 28.545324 .
# After 580 step : w is 4.341714, loss is 28.533907 .
# After 581 step : w is 4.340646, loss is 28.522497 .
# After 582 step : w is 4.339578, loss is 28.511089 .
# After 583 step : w is 4.338510, loss is 28.499683 .
# After 584 step : w is 4.337442, loss is 28.488287 .
# After 585 step : w is 4.336374, loss is 28.476891 .
# After 586 step : w is 4.335307, loss is 28.465502 .
# After 587 step : w is 4.334240, loss is 28.454117 .
# After 588 step : w is 4.333173, loss is 28.442738 .
# After 589 step : w is 4.332107, loss is 28.431360 .
# After 590 step : w is 4.331040, loss is 28.419992 .
# After 591 step : w is 4.329974, loss is 28.408625 .
# After 592 step : w is 4.328908, loss is 28.397261 .
# After 593 step : w is 4.327842, loss is 28.385902 .
# After 594 step : w is 4.326777, loss is 28.374548 .
# After 595 step : w is 4.325711, loss is 28.363201 .
# After 596 step : w is 4.324646, loss is 28.351854 .
# After 597 step : w is 4.323581, loss is 28.340517 .
# After 598 step : w is 4.322516, loss is 28.329182 .
# After 599 step : w is 4.321452, loss is 28.317852 .
# After 600 step : w is 4.320388, loss is 28.306526 .
# After 601 step : w is 4.319324, loss is 28.295202 .
# After 602 step : w is 4.318260, loss is 28.283886 .
# After 603 step : w is 4.317196, loss is 28.272572 .
# After 604 step : w is 4.316133, loss is 28.261265 .
# After 605 step : w is 4.315069, loss is 28.249960 .
# After 606 step : w is 4.314006, loss is 28.238663 .
# After 607 step : w is 4.312943, loss is 28.227367 .
# After 608 step : w is 4.311881, loss is 28.216080 .
# After 609 step : w is 4.310819, loss is 28.204796 .
# After 610 step : w is 4.309756, loss is 28.193512 .
# After 611 step : w is 4.308694, loss is 28.182236 .
# After 612 step : w is 4.307632, loss is 28.170961 .
# After 613 step : w is 4.306571, loss is 28.159697 .
# After 614 step : w is 4.305510, loss is 28.148432 .
# After 615 step : w is 4.304449, loss is 28.137175 .
# After 616 step : w is 4.303388, loss is 28.125921 .
# After 617 step : w is 4.302327, loss is 28.114674 .
# After 618 step : w is 4.301267, loss is 28.103428 .
# After 619 step : w is 4.300206, loss is 28.092186 .
# After 620 step : w is 4.299146, loss is 28.080950 .
# After 621 step : w is 4.298086, loss is 28.069717 .
# After 622 step : w is 4.297027, loss is 28.058491 .
# After 623 step : w is 4.295967, loss is 28.047268 .
# After 624 step : w is 4.294908, loss is 28.036051 .
# After 625 step : w is 4.293849, loss is 28.024837 .
# After 626 step : w is 4.292790, loss is 28.013630 .
# After 627 step : w is 4.291732, loss is 28.002426 .
# After 628 step : w is 4.290673, loss is 27.991224 .
# After 629 step : w is 4.289615, loss is 27.980028 .
# After 630 step : w is 4.288557, loss is 27.968836 .
# After 631 step : w is 4.287499, loss is 27.957651 .
# After 632 step : w is 4.286442, loss is 27.946466 .
# After 633 step : w is 4.285385, loss is 27.935291 .
# After 634 step : w is 4.284328, loss is 27.924118 .
# After 635 step : w is 4.283271, loss is 27.912951 .
# After 636 step : w is 4.282214, loss is 27.901787 .
# After 637 step : w is 4.281157, loss is 27.890625 .
# After 638 step : w is 4.280101, loss is 27.879469 .
# After 639 step : w is 4.279045, loss is 27.868317 .
# After 640 step : w is 4.277989, loss is 27.857172 .
# After 641 step : w is 4.276934, loss is 27.846029 .
# After 642 step : w is 4.275878, loss is 27.834892 .
# After 643 step : w is 4.274823, loss is 27.823759 .
# After 644 step : w is 4.273768, loss is 27.812634 .
# After 645 step : w is 4.272714, loss is 27.801510 .
# After 646 step : w is 4.271659, loss is 27.790388 .
# After 647 step : w is 4.270605, loss is 27.779272 .
# After 648 step : w is 4.269550, loss is 27.768160 .
# After 649 step : w is 4.268497, loss is 27.757055 .
# After 650 step : w is 4.267443, loss is 27.745953 .
# After 651 step : w is 4.266389, loss is 27.734858 .
# After 652 step : w is 4.265336, loss is 27.723764 .
# After 653 step : w is 4.264283, loss is 27.712677 .
# After 654 step : w is 4.263230, loss is 27.701593 .
# After 655 step : w is 4.262177, loss is 27.690512 .
# After 656 step : w is 4.261125, loss is 27.679438 .
# After 657 step : w is 4.260073, loss is 27.668365 .
# After 658 step : w is 4.259021, loss is 27.657299 .
# After 659 step : w is 4.257969, loss is 27.646236 .
# After 660 step : w is 4.256917, loss is 27.635181 .
# After 661 step : w is 4.255866, loss is 27.624128 .
# After 662 step : w is 4.254815, loss is 27.613081 .
# After 663 step : w is 4.253764, loss is 27.602037 .
# After 664 step : w is 4.252713, loss is 27.590996 .
# After 665 step : w is 4.251663, loss is 27.579962 .
# After 666 step : w is 4.250612, loss is 27.568930 .
# After 667 step : w is 4.249562, loss is 27.557903 .
# After 668 step : w is 4.248512, loss is 27.546881 .
# After 669 step : w is 4.247463, loss is 27.535866 .
# After 670 step : w is 4.246413, loss is 27.524851 .
# After 671 step : w is 4.245364, loss is 27.513840 .
# After 672 step : w is 4.244315, loss is 27.502836 .
# After 673 step : w is 4.243266, loss is 27.491835 .
# After 674 step : w is 4.242217, loss is 27.480841 .
# After 675 step : w is 4.241168, loss is 27.469847 .
# After 676 step : w is 4.240120, loss is 27.458862 .
# After 677 step : w is 4.239072, loss is 27.447878 .
# After 678 step : w is 4.238025, loss is 27.436903 .
# After 679 step : w is 4.236977, loss is 27.425930 .
# After 680 step : w is 4.235929, loss is 27.414957 .
# After 681 step : w is 4.234882, loss is 27.403994 .
# After 682 step : w is 4.233835, loss is 27.393030 .
# After 683 step : w is 4.232789, loss is 27.382076 .
# After 684 step : w is 4.231742, loss is 27.371124 .
# After 685 step : w is 4.230696, loss is 27.360178 .
# After 686 step : w is 4.229650, loss is 27.349234 .
# After 687 step : w is 4.228604, loss is 27.338299 .
# After 688 step : w is 4.227558, loss is 27.327364 .
# After 689 step : w is 4.226512, loss is 27.316433 .
# After 690 step : w is 4.225467, loss is 27.305508 .
# After 691 step : w is 4.224422, loss is 27.294584 .
# After 692 step : w is 4.223377, loss is 27.283670 .
# After 693 step : w is 4.222332, loss is 27.272757 .
# After 694 step : w is 4.221288, loss is 27.261850 .
# After 695 step : w is 4.220244, loss is 27.250946 .
# After 696 step : w is 4.219200, loss is 27.240046 .
# After 697 step : w is 4.218156, loss is 27.229151 .
# After 698 step : w is 4.217112, loss is 27.218258 .
# After 699 step : w is 4.216069, loss is 27.207373 .
# After 700 step : w is 4.215025, loss is 27.196489 .
# After 701 step : w is 4.213983, loss is 27.185614 .
# After 702 step : w is 4.212940, loss is 27.174740 .
# After 703 step : w is 4.211897, loss is 27.163874 .
# After 704 step : w is 4.210855, loss is 27.153009 .
# After 705 step : w is 4.209813, loss is 27.142147 .
# After 706 step : w is 4.208771, loss is 27.131292 .
# After 707 step : w is 4.207729, loss is 27.120440 .
# After 708 step : w is 4.206687, loss is 27.109594 .
# After 709 step : w is 4.205646, loss is 27.098751 .
# After 710 step : w is 4.204605, loss is 27.087914 .
# After 711 step : w is 4.203564, loss is 27.077080 .
# After 712 step : w is 4.202523, loss is 27.066248 .
# After 713 step : w is 4.201483, loss is 27.055424 .
# After 714 step : w is 4.200442, loss is 27.044600 .
# After 715 step : w is 4.199402, loss is 27.033785 .
# After 716 step : w is 4.198362, loss is 27.022970 .
# After 717 step : w is 4.197323, loss is 27.012165 .
# After 718 step : w is 4.196283, loss is 27.001360 .
# After 719 step : w is 4.195244, loss is 26.990564 .
# After 720 step : w is 4.194205, loss is 26.979769 .
# After 721 step : w is 4.193166, loss is 26.968975 .
# After 722 step : w is 4.192128, loss is 26.958191 .
# After 723 step : w is 4.191089, loss is 26.947407 .
# After 724 step : w is 4.190051, loss is 26.936630 .
# After 725 step : w is 4.189013, loss is 26.925856 .
# After 726 step : w is 4.187975, loss is 26.915089 .
# After 727 step : w is 4.186938, loss is 26.904324 .
# After 728 step : w is 4.185900, loss is 26.893560 .
# After 729 step : w is 4.184863, loss is 26.882805 .
# After 730 step : w is 4.183826, loss is 26.872051 .
# After 731 step : w is 4.182789, loss is 26.861305 .
# After 732 step : w is 4.181753, loss is 26.850561 .
# After 733 step : w is 4.180717, loss is 26.839823 .
# After 734 step : w is 4.179680, loss is 26.829088 .
# After 735 step : w is 4.178644, loss is 26.818356 .
# After 736 step : w is 4.177608, loss is 26.807631 .
# After 737 step : w is 4.176573, loss is 26.796906 .
# After 738 step : w is 4.175538, loss is 26.786190 .
# After 739 step : w is 4.174502, loss is 26.775475 .
# After 740 step : w is 4.173468, loss is 26.764767 .
# After 741 step : w is 4.172433, loss is 26.754063 .
# After 742 step : w is 4.171399, loss is 26.743364 .
# After 743 step : w is 4.170364, loss is 26.732668 .
# After 744 step : w is 4.169330, loss is 26.721973 .
# After 745 step : w is 4.168296, loss is 26.711287 .
# After 746 step : w is 4.167263, loss is 26.700602 .
# After 747 step : w is 4.166229, loss is 26.689924 .
# After 748 step : w is 4.165196, loss is 26.679249 .
# After 749 step : w is 4.164163, loss is 26.668581 .
# After 750 step : w is 4.163130, loss is 26.657915 .
# After 751 step : w is 4.162097, loss is 26.647249 .
# After 752 step : w is 4.161065, loss is 26.636593 .
# After 753 step : w is 4.160033, loss is 26.625938 .
# After 754 step : w is 4.159001, loss is 26.615290 .
# After 755 step : w is 4.157969, loss is 26.604645 .
# After 756 step : w is 4.156938, loss is 26.594006 .
# After 757 step : w is 4.155906, loss is 26.583368 .
# After 758 step : w is 4.154875, loss is 26.572735 .
# After 759 step : w is 4.153844, loss is 26.562107 .
# After 760 step : w is 4.152813, loss is 26.551481 .
# After 761 step : w is 4.151783, loss is 26.540863 .
# After 762 step : w is 4.150752, loss is 26.530247 .
# After 763 step : w is 4.149722, loss is 26.519638 .
# After 764 step : w is 4.148692, loss is 26.509031 .
# After 765 step : w is 4.147662, loss is 26.498426 .
# After 766 step : w is 4.146633, loss is 26.487827 .
# After 767 step : w is 4.145603, loss is 26.477232 .
# After 768 step : w is 4.144574, loss is 26.466644 .
# After 769 step : w is 4.143545, loss is 26.456057 .
# After 770 step : w is 4.142517, loss is 26.445477 .
# After 771 step : w is 4.141488, loss is 26.434900 .
# After 772 step : w is 4.140460, loss is 26.424330 .
# After 773 step : w is 4.139432, loss is 26.413761 .
# After 774 step : w is 4.138404, loss is 26.403194 .
# After 775 step : w is 4.137376, loss is 26.392635 .
# After 776 step : w is 4.136349, loss is 26.382078 .
# After 777 step : w is 4.135322, loss is 26.371529 .
# After 778 step : w is 4.134295, loss is 26.360981 .
# After 779 step : w is 4.133268, loss is 26.350439 .
# After 780 step : w is 4.132241, loss is 26.339901 .
# After 781 step : w is 4.131215, loss is 26.329363 .
# After 782 step : w is 4.130188, loss is 26.318834 .
# After 783 step : w is 4.129162, loss is 26.308306 .
# After 784 step : w is 4.128137, loss is 26.297785 .
# After 785 step : w is 4.127111, loss is 26.287268 .
# After 786 step : w is 4.126086, loss is 26.276754 .
# After 787 step : w is 4.125061, loss is 26.266245 .
# After 788 step : w is 4.124035, loss is 26.255739 .
# After 789 step : w is 4.123011, loss is 26.245237 .
# After 790 step : w is 4.121986, loss is 26.234739 .
# After 791 step : w is 4.120962, loss is 26.224249 .
# After 792 step : w is 4.119937, loss is 26.213758 .
# After 793 step : w is 4.118914, loss is 26.203278 .
# After 794 step : w is 4.117890, loss is 26.192797 .
# After 795 step : w is 4.116866, loss is 26.182320 .
# After 796 step : w is 4.115843, loss is 26.171848 .
# After 797 step : w is 4.114820, loss is 26.161379 .
# After 798 step : w is 4.113797, loss is 26.150917 .
# After 799 step : w is 4.112774, loss is 26.140457 .
# After 800 step : w is 4.111752, loss is 26.130005 .
# After 801 step : w is 4.110729, loss is 26.119553 .
# After 802 step : w is 4.109707, loss is 26.109104 .
# After 803 step : w is 4.108685, loss is 26.098663 .
# After 804 step : w is 4.107663, loss is 26.088223 .
# After 805 step : w is 4.106642, loss is 26.077789 .
# After 806 step : w is 4.105620, loss is 26.067360 .
# After 807 step : w is 4.104599, loss is 26.056936 .
# After 808 step : w is 4.103579, loss is 26.046515 .
# After 809 step : w is 4.102558, loss is 26.036095 .
# After 810 step : w is 4.101537, loss is 26.025682 .
# After 811 step : w is 4.100517, loss is 26.015272 .
# After 812 step : w is 4.099497, loss is 26.004868 .
# After 813 step : w is 4.098477, loss is 25.994467 .
# After 814 step : w is 4.097457, loss is 25.984072 .
# After 815 step : w is 4.096438, loss is 25.973680 .
# After 816 step : w is 4.095418, loss is 25.963289 .
# After 817 step : w is 4.094399, loss is 25.952906 .
# After 818 step : w is 4.093380, loss is 25.942524 .
# After 819 step : w is 4.092362, loss is 25.932150 .
# After 820 step : w is 4.091343, loss is 25.921778 .
# After 821 step : w is 4.090325, loss is 25.911411 .
# After 822 step : w is 4.089307, loss is 25.901049 .
# After 823 step : w is 4.088289, loss is 25.890688 .
# After 824 step : w is 4.087272, loss is 25.880333 .
# After 825 step : w is 4.086254, loss is 25.869982 .
# After 826 step : w is 4.085237, loss is 25.859636 .
# After 827 step : w is 4.084220, loss is 25.849293 .
# After 828 step : w is 4.083203, loss is 25.838957 .
# After 829 step : w is 4.082187, loss is 25.828621 .
# After 830 step : w is 4.081170, loss is 25.818289 .
# After 831 step : w is 4.080154, loss is 25.807964 .
# After 832 step : w is 4.079138, loss is 25.797642 .
# After 833 step : w is 4.078122, loss is 25.787325 .
# After 834 step : w is 4.077106, loss is 25.777010 .
# After 835 step : w is 4.076091, loss is 25.766703 .
# After 836 step : w is 4.075076, loss is 25.756397 .
# After 837 step : w is 4.074061, loss is 25.746094 .
# After 838 step : w is 4.073046, loss is 25.735798 .
# After 839 step : w is 4.072031, loss is 25.725504 .
# After 840 step : w is 4.071017, loss is 25.715216 .
# After 841 step : w is 4.070003, loss is 25.704931 .
# After 842 step : w is 4.068989, loss is 25.694647 .
# After 843 step : w is 4.067975, loss is 25.684372 .
# After 844 step : w is 4.066961, loss is 25.674097 .
# After 845 step : w is 4.065948, loss is 25.663830 .
# After 846 step : w is 4.064935, loss is 25.653564 .
# After 847 step : w is 4.063922, loss is 25.643305 .
# After 848 step : w is 4.062909, loss is 25.633049 .
# After 849 step : w is 4.061896, loss is 25.622795 .
# After 850 step : w is 4.060884, loss is 25.612547 .
# After 851 step : w is 4.059872, loss is 25.602301 .
# After 852 step : w is 4.058860, loss is 25.592062 .
# After 853 step : w is 4.057848, loss is 25.581825 .
# After 854 step : w is 4.056837, loss is 25.571596 .
# After 855 step : w is 4.055825, loss is 25.561369 .
# After 856 step : w is 4.054814, loss is 25.551144 .
# After 857 step : w is 4.053803, loss is 25.540924 .
# After 858 step : w is 4.052792, loss is 25.530708 .
# After 859 step : w is 4.051782, loss is 25.520498 .
# After 860 step : w is 4.050771, loss is 25.510290 .
# After 861 step : w is 4.049761, loss is 25.500090 .
# After 862 step : w is 4.048751, loss is 25.489891 .
# After 863 step : w is 4.047741, loss is 25.479692 .
# After 864 step : w is 4.046732, loss is 25.469503 .
# After 865 step : w is 4.045722, loss is 25.459316 .
# After 866 step : w is 4.044713, loss is 25.449135 .
# After 867 step : w is 4.043705, loss is 25.438955 .
# After 868 step : w is 4.042696, loss is 25.428783 .
# After 869 step : w is 4.041687, loss is 25.418613 .
# After 870 step : w is 4.040679, loss is 25.408445 .
# After 871 step : w is 4.039671, loss is 25.398283 .
# After 872 step : w is 4.038663, loss is 25.388124 .
# After 873 step : w is 4.037655, loss is 25.377972 .
# After 874 step : w is 4.036648, loss is 25.367821 .
# After 875 step : w is 4.035640, loss is 25.357672 .
# After 876 step : w is 4.034633, loss is 25.347530 .
# After 877 step : w is 4.033626, loss is 25.337391 .
# After 878 step : w is 4.032619, loss is 25.327259 .
# After 879 step : w is 4.031613, loss is 25.317127 .
# After 880 step : w is 4.030607, loss is 25.307005 .
# After 881 step : w is 4.029601, loss is 25.296883 .
# After 882 step : w is 4.028594, loss is 25.286762 .
# After 883 step : w is 4.027589, loss is 25.276649 .
# After 884 step : w is 4.026583, loss is 25.266539 .
# After 885 step : w is 4.025578, loss is 25.256435 .
# After 886 step : w is 4.024573, loss is 25.246332 .
# After 887 step : w is 4.023568, loss is 25.236237 .
# After 888 step : w is 4.022563, loss is 25.226143 .
# After 889 step : w is 4.021559, loss is 25.216053 .
# After 890 step : w is 4.020555, loss is 25.205969 .
# After 891 step : w is 4.019550, loss is 25.195885 .
# After 892 step : w is 4.018547, loss is 25.185810 .
# After 893 step : w is 4.017543, loss is 25.175735 .
# After 894 step : w is 4.016539, loss is 25.165665 .
# After 895 step : w is 4.015536, loss is 25.155600 .
# After 896 step : w is 4.014533, loss is 25.145536 .
# After 897 step : w is 4.013530, loss is 25.135481 .
# After 898 step : w is 4.012527, loss is 25.125427 .
# After 899 step : w is 4.011525, loss is 25.115379 .
# After 900 step : w is 4.010522, loss is 25.105335 .
# After 901 step : w is 4.009520, loss is 25.095291 .
# After 902 step : w is 4.008518, loss is 25.085255 .
# After 903 step : w is 4.007516, loss is 25.075220 .
# After 904 step : w is 4.006515, loss is 25.065193 .
# After 905 step : w is 4.005514, loss is 25.055166 .
# After 906 step : w is 4.004513, loss is 25.045149 .
# After 907 step : w is 4.003512, loss is 25.035131 .
# After 908 step : w is 4.002511, loss is 25.025116 .
# After 909 step : w is 4.001511, loss is 25.015108 .
# After 910 step : w is 4.000510, loss is 25.005102 .
# After 911 step : w is 3.999510, loss is 24.995098 .
# After 912 step : w is 3.998510, loss is 24.985106 .
# After 913 step : w is 3.997510, loss is 24.975111 .
# After 914 step : w is 3.996511, loss is 24.965122 .
# After 915 step : w is 3.995512, loss is 24.955141 .
# After 916 step : w is 3.994513, loss is 24.945156 .
# After 917 step : w is 3.993514, loss is 24.935179 .
# After 918 step : w is 3.992515, loss is 24.925201 .
# After 919 step : w is 3.991516, loss is 24.915234 .
# After 920 step : w is 3.990518, loss is 24.905272 .
# After 921 step : w is 3.989520, loss is 24.895311 .
# After 922 step : w is 3.988522, loss is 24.885353 .
# After 923 step : w is 3.987524, loss is 24.875397 .
# After 924 step : w is 3.986527, loss is 24.865446 .
# ...
# After 3693 step : w is 1.865907, loss is 8.213426 .
# After 3694 step : w is 1.865334, loss is 8.210140 .
# After 3695 step : w is 1.864761, loss is 8.206858 .
# After 3696 step : w is 1.864188, loss is 8.203574 .
# After 3697 step : w is 1.863616, loss is 8.200294 .
# After 3698 step : w is 1.863043, loss is 8.197014 .
# After 3699 step : w is 1.862470, loss is 8.193735 .
# After 3700 step : w is 1.861898, loss is 8.190460 .
# After 3701 step : w is 1.861326, loss is 8.187183 .
# After 3702 step : w is 1.860753, loss is 8.183908 .
# After 3703 step : w is 1.860181, loss is 8.180634 .
# After 3704 step : w is 1.859609, loss is 8.177363 .
# After 3705 step : w is 1.859037, loss is 8.174092 .
# After 3706 step : w is 1.858465, loss is 8.170823 .
# After 3707 step : w is 1.857893, loss is 8.167555 .
# After 3708 step : w is 1.857322, loss is 8.164288 .
# After 3709 step : w is 1.856750, loss is 8.161022 .
# After 3710 step : w is 1.856179, loss is 8.157757 .
# After 3711 step : w is 1.855608, loss is 8.154494 .
# After 3712 step : w is 1.855036, loss is 8.151234 .
# After 3713 step : w is 1.854465, loss is 8.147973 .
# After 3714 step : w is 1.853895, loss is 8.144715 .
# After 3715 step : w is 1.853324, loss is 8.141458 .
# After 3716 step : w is 1.852753, loss is 8.138201 .
# After 3717 step : w is 1.852183, loss is 8.134946 .
# After 3718 step : w is 1.851612, loss is 8.131692 .
# After 3719 step : w is 1.851042, loss is 8.128439 .
# After 3720 step : w is 1.850472, loss is 8.125189 .
# After 3721 step : w is 1.849902, loss is 8.121940 .
# After 3722 step : w is 1.849332, loss is 8.118692 .
# After 3723 step : w is 1.848762, loss is 8.115445 .
# After 3724 step : w is 1.848192, loss is 8.112199 .
# After 3725 step : w is 1.847623, loss is 8.108954 .
# After 3726 step : w is 1.847053, loss is 8.105711 .
# After 3727 step : w is 1.846484, loss is 8.102469 .
# After 3728 step : w is 1.845914, loss is 8.099229 .
# After 3729 step : w is 1.845345, loss is 8.095988 .
# After 3730 step : w is 1.844776, loss is 8.092750 .
# After 3731 step : w is 1.844207, loss is 8.089513 .
# After 3732 step : w is 1.843638, loss is 8.086277 .
# After 3733 step : w is 1.843069, loss is 8.083043 .
# After 3734 step : w is 1.842501, loss is 8.079810 .
# After 3735 step : w is 1.841932, loss is 8.076579 .
# After 3736 step : w is 1.841364, loss is 8.073349 .
# After 3737 step : w is 1.840796, loss is 8.070119 .
# After 3738 step : w is 1.840227, loss is 8.066892 .
# After 3739 step : w is 1.839659, loss is 8.063664 .
# After 3740 step : w is 1.839091, loss is 8.060439 .
# After 3741 step : w is 1.838524, loss is 8.057217 .
# After 3742 step : w is 1.837956, loss is 8.053994 .
# After 3743 step : w is 1.837388, loss is 8.050774 .
# After 3744 step : w is 1.836821, loss is 8.047554 .
# After 3745 step : w is 1.836254, loss is 8.044334 .
# After 3746 step : w is 1.835686, loss is 8.041118 .
# After 3747 step : w is 1.835119, loss is 8.037901 .
# After 3748 step : w is 1.834552, loss is 8.034687 .
# After 3749 step : w is 1.833985, loss is 8.031473 .
# After 3750 step : w is 1.833418, loss is 8.028259 .
# After 3751 step : w is 1.832852, loss is 8.025050 .
# After 3752 step : w is 1.832285, loss is 8.021839 .
# After 3753 step : w is 1.831719, loss is 8.018631 .
# After 3754 step : w is 1.831152, loss is 8.015424 .
# After 3755 step : w is 1.830586, loss is 8.012217 .
# After 3756 step : w is 1.830020, loss is 8.009013 .
# After 3757 step : w is 1.829454, loss is 8.005810 .
# After 3758 step : w is 1.828888, loss is 8.002607 .
# After 3759 step : w is 1.828322, loss is 7.999408 .
# After 3760 step : w is 1.827757, loss is 7.996208 .
# After 3761 step : w is 1.827191, loss is 7.993010 .
# After 3762 step : w is 1.826626, loss is 7.989813 .
# After 3763 step : w is 1.826060, loss is 7.986617 .
# After 3764 step : w is 1.825495, loss is 7.983423 .
# After 3765 step : w is 1.824930, loss is 7.980231 .
# After 3766 step : w is 1.824365, loss is 7.977038 .
# After 3767 step : w is 1.823800, loss is 7.973850 .
# After 3768 step : w is 1.823236, loss is 7.970659 .
# After 3769 step : w is 1.822671, loss is 7.967471 .
# After 3770 step : w is 1.822106, loss is 7.964284 .
# After 3771 step : w is 1.821542, loss is 7.961098 .
# After 3772 step : w is 1.820978, loss is 7.957915 .
# After 3773 step : w is 1.820413, loss is 7.954731 .
# After 3774 step : w is 1.819849, loss is 7.951550 .
# After 3775 step : w is 1.819285, loss is 7.948370 .
# After 3776 step : w is 1.818721, loss is 7.945190 .
# After 3777 step : w is 1.818158, loss is 7.942013 .
# After 3778 step : w is 1.817594, loss is 7.938836 .
# After 3779 step : w is 1.817031, loss is 7.935660 .
# After 3780 step : w is 1.816467, loss is 7.932488 .
# After 3781 step : w is 1.815904, loss is 7.929315 .
# After 3782 step : w is 1.815341, loss is 7.926144 .
# After 3783 step : w is 1.814778, loss is 7.922975 .
# After 3784 step : w is 1.814215, loss is 7.919805 .
# After 3785 step : w is 1.813652, loss is 7.916638 .
# After 3786 step : w is 1.813089, loss is 7.913472 .
# After 3787 step : w is 1.812527, loss is 7.910306 .
# After 3788 step : w is 1.811964, loss is 7.907142 .
# After 3789 step : w is 1.811402, loss is 7.903979 .
# After 3790 step : w is 1.810839, loss is 7.900817 .
# After 3791 step : w is 1.810277, loss is 7.897657 .
# After 3792 step : w is 1.809715, loss is 7.894498 .
# After 3793 step : w is 1.809153, loss is 7.891341 .
# After 3794 step : w is 1.808591, loss is 7.888186 .
# After 3795 step : w is 1.808030, loss is 7.885031 .
# After 3796 step : w is 1.807468, loss is 7.881876 .
# After 3797 step : w is 1.806906, loss is 7.878724 .
# After 3798 step : w is 1.806345, loss is 7.875572 .
# After 3799 step : w is 1.805784, loss is 7.872422 .
# After 3800 step : w is 1.805223, loss is 7.869275 .
# After 3801 step : w is 1.804662, loss is 7.866127 .
# After 3802 step : w is 1.804101, loss is 7.862982 .
# After 3803 step : w is 1.803540, loss is 7.859837 .
# After 3804 step : w is 1.802979, loss is 7.856693 .
# After 3805 step : w is 1.802419, loss is 7.853550 .
# After 3806 step : w is 1.801858, loss is 7.850408 .
# After 3807 step : w is 1.801298, loss is 7.847269 .
# After 3808 step : w is 1.800737, loss is 7.844130 .
# After 3809 step : w is 1.800177, loss is 7.840992 .
# After 3810 step : w is 1.799617, loss is 7.837857 .
# After 3811 step : w is 1.799057, loss is 7.834722 .
# After 3812 step : w is 1.798497, loss is 7.831588 .
# After 3813 step : w is 1.797938, loss is 7.828456 .
# After 3814 step : w is 1.797378, loss is 7.825324 .
# After 3815 step : w is 1.796819, loss is 7.822195 .
# After 3816 step : w is 1.796259, loss is 7.819067 .
# After 3817 step : w is 1.795700, loss is 7.815939 .
# After 3818 step : w is 1.795141, loss is 7.812814 .
# After 3819 step : w is 1.794582, loss is 7.809689 .
# After 3820 step : w is 1.794023, loss is 7.806565 .
# After 3821 step : w is 1.793464, loss is 7.803442 .
# After 3822 step : w is 1.792906, loss is 7.800322 .
# After 3823 step : w is 1.792347, loss is 7.797202 .
# After 3824 step : w is 1.791788, loss is 7.794084 .
# After 3825 step : w is 1.791230, loss is 7.790966 .
# After 3826 step : w is 1.790672, loss is 7.787849 .
# After 3827 step : w is 1.790114, loss is 7.784734 .
# After 3828 step : w is 1.789556, loss is 7.781620 .
# After 3829 step : w is 1.788998, loss is 7.778508 .
# After 3830 step : w is 1.788440, loss is 7.775398 .
# After 3831 step : w is 1.787882, loss is 7.772288 .
# After 3832 step : w is 1.787325, loss is 7.769180 .
# After 3833 step : w is 1.786767, loss is 7.766073 .
# After 3834 step : w is 1.786210, loss is 7.762967 .
# After 3835 step : w is 1.785653, loss is 7.759862 .
# After 3836 step : w is 1.785096, loss is 7.756758 .
# After 3837 step : w is 1.784539, loss is 7.753656 .
# After 3838 step : w is 1.783982, loss is 7.750555 .
# After 3839 step : w is 1.783425, loss is 7.747454 .
# After 3840 step : w is 1.782868, loss is 7.744355 .
# After 3841 step : w is 1.782312, loss is 7.741257 .
# After 3842 step : w is 1.781755, loss is 7.738161 .
# After 3843 step : w is 1.781199, loss is 7.735066 .
# After 3844 step : w is 1.780643, loss is 7.731973 .
# After 3845 step : w is 1.780086, loss is 7.728881 .
# After 3846 step : w is 1.779530, loss is 7.725790 .
# After 3847 step : w is 1.778975, loss is 7.722700 .
# After 3848 step : w is 1.778419, loss is 7.719611 .
# After 3849 step : w is 1.777863, loss is 7.716523 .
# After 3850 step : w is 1.777308, loss is 7.713437 .
# After 3851 step : w is 1.776752, loss is 7.710351 .
# After 3852 step : w is 1.776197, loss is 7.707268 .
# After 3853 step : w is 1.775641, loss is 7.704185 .
# After 3854 step : w is 1.775086, loss is 7.701105 .
# After 3855 step : w is 1.774531, loss is 7.698024 .
# After 3856 step : w is 1.773976, loss is 7.694945 .
# After 3857 step : w is 1.773422, loss is 7.691867 .
# After 3858 step : w is 1.772867, loss is 7.688790 .
# After 3859 step : w is 1.772312, loss is 7.685715 .
# After 3860 step : w is 1.771758, loss is 7.682642 .
# After 3861 step : w is 1.771204, loss is 7.679569 .
# After 3862 step : w is 1.770649, loss is 7.676498 .
# After 3863 step : w is 1.770095, loss is 7.673428 .
# After 3864 step : w is 1.769541, loss is 7.670359 .
# After 3865 step : w is 1.768987, loss is 7.667290 .
# After 3866 step : w is 1.768433, loss is 7.664225 .
# After 3867 step : w is 1.767880, loss is 7.661158 .
# After 3868 step : w is 1.767326, loss is 7.658094 .
# After 3869 step : w is 1.766773, loss is 7.655031 .
# After 3870 step : w is 1.766219, loss is 7.651968 .
# After 3871 step : w is 1.765666, loss is 7.648909 .
# After 3872 step : w is 1.765113, loss is 7.645849 .
# After 3873 step : w is 1.764560, loss is 7.642791 .
# After 3874 step : w is 1.764007, loss is 7.639735 .
# After 3875 step : w is 1.763454, loss is 7.636679 .
# After 3876 step : w is 1.762902, loss is 7.633625 .
# After 3877 step : w is 1.762349, loss is 7.630573 .
# After 3878 step : w is 1.761797, loss is 7.627520 .
# After 3879 step : w is 1.761244, loss is 7.624470 .
# After 3880 step : w is 1.760692, loss is 7.621419 .
# After 3881 step : w is 1.760140, loss is 7.618371 .
# After 3882 step : w is 1.759588, loss is 7.615324 .
# After 3883 step : w is 1.759036, loss is 7.612278 .
# After 3884 step : w is 1.758484, loss is 7.609233 .
# After 3885 step : w is 1.757932, loss is 7.606190 .
# After 3886 step : w is 1.757381, loss is 7.603147 .
# After 3887 step : w is 1.756829, loss is 7.600108 .
# After 3888 step : w is 1.756278, loss is 7.597067 .
# After 3889 step : w is 1.755727, loss is 7.594029 .
# After 3890 step : w is 1.755175, loss is 7.590992 .
# After 3891 step : w is 1.754624, loss is 7.587955 .
# After 3892 step : w is 1.754074, loss is 7.584921 .
# After 3893 step : w is 1.753523, loss is 7.581888 .
# After 3894 step : w is 1.752972, loss is 7.578856 .
# After 3895 step : w is 1.752421, loss is 7.575823 .
# After 3896 step : w is 1.751871, loss is 7.572793 .
# After 3897 step : w is 1.751320, loss is 7.569764 .
# After 3898 step : w is 1.750770, loss is 7.566736 .
# After 3899 step : w is 1.750220, loss is 7.563710 .
# After 3900 step : w is 1.749670, loss is 7.560685 .
# After 3901 step : w is 1.749120, loss is 7.557662 .
# After 3902 step : w is 1.748570, loss is 7.554639 .
# After 3903 step : w is 1.748021, loss is 7.551618 .
# After 3904 step : w is 1.747471, loss is 7.548597 .
# After 3905 step : w is 1.746922, loss is 7.545578 .
# After 3906 step : w is 1.746372, loss is 7.542561 .
# After 3907 step : w is 1.745823, loss is 7.539544 .
# After 3908 step : w is 1.745274, loss is 7.536527 .
# After 3909 step : w is 1.744725, loss is 7.533514 .
# After 3910 step : w is 1.744176, loss is 7.530500 .
# After 3911 step : w is 1.743627, loss is 7.527488 .
# After 3912 step : w is 1.743078, loss is 7.524478 .
# After 3913 step : w is 1.742530, loss is 7.521468 .
# After 3914 step : w is 1.741981, loss is 7.518460 .
# After 3915 step : w is 1.741433, loss is 7.515453 .
# After 3916 step : w is 1.740884, loss is 7.512447 .
# After 3917 step : w is 1.740336, loss is 7.509444 .
# After 3918 step : w is 1.739788, loss is 7.506439 .
# After 3919 step : w is 1.739240, loss is 7.503437 .
# After 3920 step : w is 1.738692, loss is 7.500435 .
# After 3921 step : w is 1.738145, loss is 7.497435 .
# After 3922 step : w is 1.737597, loss is 7.494437 .
# After 3923 step : w is 1.737049, loss is 7.491439 .
# After 3924 step : w is 1.736502, loss is 7.488443 .
# After 3925 step : w is 1.735955, loss is 7.485448 .
# After 3926 step : w is 1.735407, loss is 7.482453 .
# After 3927 step : w is 1.734860, loss is 7.479462 .
# After 3928 step : w is 1.734313, loss is 7.476470 .
# After 3929 step : w is 1.733767, loss is 7.473480 .
# After 3930 step : w is 1.733220, loss is 7.470492 .
# After 3931 step : w is 1.732673, loss is 7.467503 .
# After 3932 step : w is 1.732127, loss is 7.464516 .
# After 3933 step : w is 1.731580, loss is 7.461531 .
# After 3934 step : w is 1.731034, loss is 7.458546 .
# After 3935 step : w is 1.730488, loss is 7.455564 .
# After 3936 step : w is 1.729942, loss is 7.452581 .
# After 3937 step : w is 1.729396, loss is 7.449601 .
# After 3938 step : w is 1.728850, loss is 7.446622 .
# After 3939 step : w is 1.728304, loss is 7.443642 .
# After 3940 step : w is 1.727758, loss is 7.440666 .
# After 3941 step : w is 1.727213, loss is 7.437690 .
# After 3942 step : w is 1.726667, loss is 7.434715 .
# After 3943 step : w is 1.726122, loss is 7.431741 .
# After 3944 step : w is 1.725577, loss is 7.428769 .
# After 3945 step : w is 1.725032, loss is 7.425797 .
# After 3946 step : w is 1.724487, loss is 7.422827 .
# After 3947 step : w is 1.723942, loss is 7.419859 .
# After 3948 step : w is 1.723397, loss is 7.416890 .
# After 3949 step : w is 1.722852, loss is 7.413924 .
# After 3950 step : w is 1.722308, loss is 7.410959 .
# After 3951 step : w is 1.721763, loss is 7.407995 .
# After 3952 step : w is 1.721219, loss is 7.405033 .
# After 3953 step : w is 1.720675, loss is 7.402071 .
# After 3954 step : w is 1.720131, loss is 7.399110 .
# After 3955 step : w is 1.719586, loss is 7.396150 .
# After 3956 step : w is 1.719043, loss is 7.393192 .
# After 3957 step : w is 1.718499, loss is 7.390235 .
# After 3958 step : w is 1.717955, loss is 7.387280 .
# After 3959 step : w is 1.717411, loss is 7.384326 .
# After 3960 step : w is 1.716868, loss is 7.381371 .
# After 3961 step : w is 1.716325, loss is 7.378419 .
# After 3962 step : w is 1.715781, loss is 7.375468 .
# After 3963 step : w is 1.715238, loss is 7.372518 .
# After 3964 step : w is 1.714695, loss is 7.369570 .
# After 3965 step : w is 1.714152, loss is 7.366623 .
# After 3966 step : w is 1.713609, loss is 7.363675 .
# After 3967 step : w is 1.713067, loss is 7.360730 .
# After 3968 step : w is 1.712524, loss is 7.357786 .
# After 3969 step : w is 1.711981, loss is 7.354843 .
# After 3970 step : w is 1.711439, loss is 7.351902 .
# After 3971 step : w is 1.710897, loss is 7.348961 .
# After 3972 step : w is 1.710355, loss is 7.346022 .
# After 3973 step : w is 1.709813, loss is 7.343084 .
# After 3974 step : w is 1.709271, loss is 7.340147 .
# After 3975 step : w is 1.708729, loss is 7.337212 .
# After 3976 step : w is 1.708187, loss is 7.334277 .
# After 3977 step : w is 1.707645, loss is 7.331344 .
# After 3978 step : w is 1.707104, loss is 7.328411 .
# After 3979 step : w is 1.706562, loss is 7.325480 .
# After 3980 step : w is 1.706021, loss is 7.322550 .
# After 3981 step : w is 1.705480, loss is 7.319621 .
# After 3982 step : w is 1.704939, loss is 7.316694 .
# After 3983 step : w is 1.704398, loss is 7.313767 .
# After 3984 step : w is 1.703857, loss is 7.310843 .
# After 3985 step : w is 1.703316, loss is 7.307919 .
# After 3986 step : w is 1.702776, loss is 7.304995 .
# After 3987 step : w is 1.702235, loss is 7.302074 .
# After 3988 step : w is 1.701694, loss is 7.299153 .
# After 3989 step : w is 1.701154, loss is 7.296234 .
# After 3990 step : w is 1.700614, loss is 7.293316 .
# After 3991 step : w is 1.700074, loss is 7.290398 .
# After 3992 step : w is 1.699534, loss is 7.287482 .
# After 3993 step : w is 1.698994, loss is 7.284567 .
# After 3994 step : w is 1.698454, loss is 7.281653 .
# After 3995 step : w is 1.697914, loss is 7.278742 .
# After 3996 step : w is 1.697375, loss is 7.275831 .
# After 3997 step : w is 1.696835, loss is 7.272922 .
# After 3998 step : w is 1.696296, loss is 7.270012 .
# After 3999 step : w is 1.695757, loss is 7.267104 .

# %% [markdown]
# ### 指数衰减学习率

# %%
LEARNING_RATE_BASE=0.1
LEARNING_RATE_DECAY=0.99
LEARNING_RATE_STEP=1

# %%
global_step=tf.Variable(0,trainable=False)

# %%
learning_rate=tf.train.exponential_decay(LEARNING_RATE_BASE,
                                         global_step,
                                         LEARNING_RATE_STEP,
                                         LEARNING_RATE_DECAY,
                                         staircase=True)

# %%
w=tf.Variable(tf.constant(5,dtype=tf.float32))
loss=tf.square(w+1)

# %%
train_step=tf.train.GradientDescentOptimizer(learning_rate).minimize(loss,global_step)

# %%
with tf.Session() as sess:
    init_op=tf.global_variables_initializer()
    sess.run(init_op)
    for i in range(40):
        sess.run(train_step)
        w_val=sess.run(w)
        loss_val=sess.run(loss)
        print("After %s step : w is %f, loss is %f ."%(sess.run(global_step),
                                                       w_val,loss_val))
# Out:
# After 1 step : w is 3.800000, loss is 23.040001 .
# After 2 step : w is 2.849600, loss is 14.819419 .
# After 3 step : w is 2.095001, loss is 9.579033 .
# After 4 step : w is 1.494386, loss is 6.221961 .
# After 5 step : w is 1.015167, loss is 4.060896 .
# After 6 step : w is 0.631886, loss is 2.663051 .
# After 7 step : w is 0.324608, loss is 1.754587 .
# After 8 step : w is 0.077684, loss is 1.161403 .
# After 9 step : w is -0.121202, loss is 0.772287 .
# After 10 step : w is -0.281761, loss is 0.515867 .
# After 11 step : w is -0.411674, loss is 0.346128 .
# After 12 step : w is -0.517024, loss is 0.233266 .
# After 13 step : w is -0.602644, loss is 0.157891 .
# After 14 step : w is -0.672382, loss is 0.107334 .
# After 15 step : w is -0.729305, loss is 0.073276 .
# After 16 step : w is -0.775868, loss is 0.050235 .
# After 17 step : w is -0.814036, loss is 0.034583 .
# After 18 step : w is -0.845387, loss is 0.023905 .
# After 19 step : w is -0.871193, loss is 0.016591 .
# After 20 step : w is -0.892476, loss is 0.011561 .
# After 21 step : w is -0.910065, loss is 0.008088 .
# After 22 step : w is -0.924629, loss is 0.005681 .
# After 23 step : w is -0.936713, loss is 0.004005 .
# After 24 step : w is -0.946758, loss is 0.002835 .
# After 25 step : w is -0.955125, loss is 0.002014 .
# After 26 step : w is -0.962106, loss is 0.001436 .
# After 27 step : w is -0.967942, loss is 0.001028 .
# After 28 step : w is -0.972830, loss is 0.000738 .
# After 29 step : w is -0.976931, loss is 0.000532 .
# After 30 step : w is -0.980378, loss is 0.000385 .
# After 31 step : w is -0.983281, loss is 0.000280 .
# After 32 step : w is -0.985730, loss is 0.000204 .
# After 33 step : w is -0.987799, loss is 0.000149 .
# After 34 step : w is -0.989550, loss is 0.000109 .
# After 35 step : w is -0.991035, loss is 0.000080 .
# After 36 step : w is -0.992297, loss is 0.000059 .
# After 37 step : w is -0.993369, loss is 0.000044 .
# After 38 step : w is -0.994284, loss is 0.000033 .
# After 39 step : w is -0.995064, loss is 0.000024 .
# After 40 step : w is -0.995731, loss is 0.000018 .
